# %% [markdown]
# # **20260704-토요실습1**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

bus_station=pd.read_excel('seoul_traffic_202605.xlsx', sheet_name='bus_station')

# %%
bus_station['버스정류장ID'] # 이 한 줄만 딱 선택, 출력한다
# Out:
# 0        8503228
# 1        8503189
# 2          72992
# 3          72314
# 4          72993
#           ...
# 41995    8503213
# 41996    8503214
# 41997    8503414
# 41998    8503215
# 41999    8503216
# Name: 버스정류장ID, Length: 42000, dtype: int64
